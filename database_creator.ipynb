# %%
import sqlite3
import pandas as pd

# File paths
exercises_file = "C:/Users/Utku/Desktop/VS Code/BIL481/exercises.csv"
coaches_file = "C:/Users/Utku/Desktop/VS Code/BIL481/coaches.csv"
users_file = "C:/Users/Utku/Desktop/VS Code/BIL481/users.csv"
db_file = "C:/Users/Utku/Desktop/VS Code/BIL481/fitness.db"

# Create a SQLite database and define tables
conn = sqlite3.connect(db_file)
cursor = conn.cursor()

# Drop tables if they already exist (for a clean start)
cursor.execute("DROP TABLE IF EXISTS Coaches;")
cursor.execute("DROP TABLE IF EXISTS Users;")
cursor.execute("DROP TABLE IF EXISTS WorkoutPlans;")
cursor.execute("DROP TABLE IF EXISTS UserFitnessData;")
cursor.execute("DROP TABLE IF EXISTS Exercises;")

# Create the Coaches table
cursor.execute("""
CREATE TABLE IF NOT EXISTS Coaches (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    name TEXT NOT NULL,
    specialization TEXT,
    age INTEGER,
    weight REAL,
    height REAL,
    experience_level INTEGER,
    password TEXT
);
""")

# Create the Users table
cursor.execute("""
CREATE TABLE IF NOT EXISTS Users (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    name TEXT NOT NULL,
    age INTEGER,
    weight REAL,
    height REAL,
    fitness_level INTEGER,
    bmi REAL,
    coach_id INTEGER,
    daily_calories INTEGER,
    goal TEXT,
    password TEXT,
    FOREIGN KEY (coach_id) REFERENCES Coaches(id)
);
""")

# Create the WorkoutPlans table
cursor.execute("""
CREATE TABLE IF NOT EXISTS WorkoutPlans (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    user_id INTEGER,
    workout_data TEXT,
    FOREIGN KEY (user_id) REFERENCES Users(id)
);
""")

# Create the UserFitnessData table
cursor.execute("""
CREATE TABLE IF NOT EXISTS UserFitnessData (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    user_id INTEGER,
    date DATE,
    exercise_name TEXT,
    weight REAL,
    sets INTEGER,
    reps INTEGER,
    FOREIGN KEY (user_id) REFERENCES Users(id)
);
""")

# Create the Exercises table
cursor.execute("""
CREATE TABLE IF NOT EXISTS Exercises (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    exercise_name TEXT NOT NULL,
    body_part TEXT,
    sets INTEGER,
    reps INTEGER,
    equipment TEXT
);
""")

# Load data from CSV files
coaches_data = pd.read_csv(coaches_file, encoding='latin1', sep=';')
users_data = pd.read_csv(users_file, encoding='latin1', sep=';')
exercises_data = pd.read_csv(exercises_file, encoding='latin1', sep=';')

# Insert data into respective tables
coaches_data.to_sql('Coaches', conn, if_exists='append', index=False)
users_data.to_sql('Users', conn, if_exists='append', index=False)
exercises_data.to_sql('Exercises', conn, if_exists='append', index=False)

# Commit changes and close the connection
conn.commit()
conn.close()

print(f"Database '{db_file}' created successfully.")
# Out:
# Database 'C:/Users/Utku/Desktop/VS Code/BIL481/fitness.db' created successfully.

# %%
import sqlite3

# SQLite database file path
db_file = "C:/Users/Utku/Desktop/VS Code/BIL481/fitness.db"

# Connect to the database
conn = sqlite3.connect(db_file)
cursor = conn.cursor()

# Function to print all tables and their contents
def print_database_contents(connection):
    cursor = connection.cursor()
    # Get a list of all tables in the database
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    tables = cursor.fetchall()
    
    for table_name in tables:
        table_name = table_name[0]
        print(f"\n--- {table_name} ---")
        
        # Fetch all rows from the current table
        cursor.execute(f"SELECT * FROM {table_name}")
        rows = cursor.fetchall()
        
        # Fetch column names for the current table
        cursor.execute(f"PRAGMA table_info({table_name})")
        columns = [col[1] for col in cursor.fetchall()]
        
        # Print column names
        print(", ".join(columns))
        
        # Print rows
        for row in rows:
            print(row)

# Call the function to print database contents
print_database_contents(conn)

# Close the connection
conn.close()
# Out:
# --- Coaches ---
# id, name, specialization, age, weight, height, experience_level, password
# (1, 'Sibel Demir', 'Strength Training, CrossFit', 29, 71.06, 179.35, 5, '1234')
# (2, 'Cem Kilic', 'Nutrition, Bodybuilding', 27, 85.96, 189.02, 3, '1234')
# (3, 'Hakan Arslan', 'Cardio, Endurance', 35, 75.0, 168.42, 2, '1234')
# (4, 'Berk Demir', 'Nutrition, Weight Loss', 35, 82.53, 189.96, 1, '1234')
# (5, 'Mustafa Demir', 'Endurance, Strength Training', 32, 84.87, 168.71, 3, '1234')
#
# --- sqlite_sequence ---
# name, seq
# ('Coaches', 5)
# ('Users', 100)
# ('Exercises', 70)
#
# --- Users ---
# id, name, age, weight, height, fitness_level, bmi, coach_id, daily_calories, goal, password
# (1, 'Ayse Guler', 37, 87.38, 153.42, 'Intermediate', 37.12, 5, 2500, 'Muscle Gain', '1234')
# (2, 'Emre Ozturk', 55, 63.72, 176.64, 'Intermediate', 20.42, 1, 2200, 'Endurance', '1234')
# (3, 'Ayse Aydin', 23, 64.57, 163.07, 'Beginner', 24.28, 1, 2300, 'Weight Loss', '1234')
# (4, 'Cem Celik', 56, 96.88, 173.53, 'Beginner', 32.17, 5, 2400, 'Weight Loss', '1234')
# (5, 'Oguz Arslan', 25, 83.85, 160.47, 'Intermediate', 32.56, 5, 2100, 'Weight Loss', '1234')
# (6, 'Oguz Sahin', 24, 75.02, 161.18, 'Beginner', 28.88, 4, 2600, 'Weight Loss', '1234')
# (7, 'Can Koc', 26, 58.01, 168.3, 'Advanced', 20.48, 3, 2800, 'Endurance', '1234')
# (8, 'Merve Celik', 18, 60.46, 157.72, 'Advanced', '24.Mar', 3, 2500, 'Weight Loss', '1234')
# (9, 'Ayse Polat', 38, 88.73, 163.83, 'Beginner', 33.06, 5, 2200, 'Weight Loss', '1234')
# (10, 'Ayse Sahin', 35, 79.75, 182.82, 'Beginner', 23.86, 3, 2300, 'Endurance', '1234')
# (11, 'Buse Guler', 30, 79.11, 153.95, 'Beginner', 33.38, 1, 2400, 'Muscle Gain', '1234')
# (12, 'Can Ozturk', 48, 68.8, 162.71, 'Advanced', 25.99, 1, 2100, 'Muscle Gain', '1234')
# (13, 'Emre Celik', 37, 66.03, 188.93, 'Beginner', '18.May', 2, 2600, 'Endurance', '1234')
# (14, 'Ayse Aydin', 52, 65.96, 179.86, 'Advanced', 20.39, 3, 2800, 'Weight Loss', '1234')
# (15, 'Can Kaya', 63, 58.92, 185.59, 'Beginner', '17.Kas', 1, 2450, 'Weight Loss', '1234')
# (16, 'Can Sahin', 53, 90.86, 161.93, 'Advanced', 34.65, 1, 2560, 'Weight Loss', '1234')
# (17, 'Ali Aksoy', 60, 78.05, 156.7, 'Intermediate', 31.79, 5, 2940, 'Endurance', '1234')
# (18, 'Can Aydin', 54, 66.5, 177.25, 'Beginner', 21.17, 5, 3120, 'Endurance', '1234')
# (19, 'Deniz Polat', 41, 92.52, 184.15, 'Intermediate', 27.28, 4, 3250, 'Endurance', '1234')
# (20, 'Buse Aydin', 58, 78.78, 180.21, 'Beginner', 24.26, 2, 2940, 'Weight Loss', '1234')
# (21, 'Deniz Demir', 25, 64.25, 168.94, 'Beginner', 22.51, 5, 2130, 'Endurance', '1234')
# (22, 'Deniz Celik', 48, 59.15, 174.03, 'Intermediate', 19.53, 1, 2500, 'Endurance', '1234')
# (23, 'Ayse Polat', 55, 62.42, 170.76, 'Beginner', 21.41, 3, 2200, 'Muscle Gain', '1234')
# (24, 'Zeynep Korkmaz', 21, 75.6, 186.19, 'Intermediate', 21.81, 3, 2300, 'Weight Loss', '1234')
# (25, 'Deniz Guler', 37, 71.45, 177.41, 'Beginner', '22.Tem', 4, 2400, 'Endurance', '1234')
# (26, 'Ahmet Guler', 42, 88.26, 177.01, 'Beginner', 28.17, 2, 2100, 'Endurance', '1234')
# (27, 'Ahmet Ozturk', 38, 90.54, 157.4, 'Intermediate', 36.55, 4, 2600, 'Weight Loss', '1234')
# (28, 'Ezgi Sahin', 29, 97.43, 178.68, 'Intermediate', 30.52, 2, 2800, 'Muscle Gain', '1234')
# (29, 'Mehmet Koc', 19, 55.63, 164.07, 'Advanced', 20.67, 3, 2500, 'Endurance', '1234')
# (30, 'Fatma Koc', 22, 65.39, 180.21, 'Advanced', 20.14, 4, 2200, 'Weight Loss', '1234')
# (31, 'Mehmet Arslan', 58, 88.55, 186.72, 'Beginner', '25.Nis', 2, 2300, 'Weight Loss', '1234')
# (32, 'Burak Korkmaz', 28, 63.91, 176.25, 'Intermediate', 20.57, 4, 2400, 'Endurance', '1234')
# (33, 'Cem Sahin', 32, 78.22, 156.29, 'Beginner', 32.02, 4, 2100, 'Endurance', '1234')
# (34, 'Mehmet Aydin', 26, 97.57, 187.35, 'Intermediate', '27.Aðu', 1, 2600, 'Muscle Gain', '1234')
# (35, 'Cem Koc', 62, 92.84, 156.93, 'Intermediate', 37.7, 5, 2800, 'Weight Loss', '1234')
# (36, 'Ezgi Aksoy', 53, 68.74, 156.19, 'Beginner', 28.18, 2, 2450, 'Endurance', '1234')
# (37, 'Burak Celik', 42, 66.63, 155.13, 'Beginner', 27.69, 4, 2560, 'Weight Loss', '1234')
# (38, 'Ali Koc', 19, 80.7, 188.43, 'Beginner', 22.73, 2, 2940, 'Endurance', '1234')
# (39, 'Burak Guler', 50, 63.16, 188.86, 'Advanced', 17.71, 4, 3120, 'Weight Loss', '1234')
# (40, 'Fatma Ozturk', 20, 77.11, 164.11, 'Beginner', 28.63, 5, 3250, 'Endurance', '1234')
# (41, 'Deniz Arslan', 43, 83.84, 168.46, 'Advanced', 29.54, 3, 2940, 'Weight Loss', '1234')
# (42, 'Merve Kaya', 38, 89.25, 172.6, 'Beginner', 29.96, 5, 2130, 'Endurance', '1234')
# (43, 'Cem Yilmaz', 27, 79.75, 178.68, 'Advanced', 24.98, 5, 2500, 'Weight Loss', '1234')
# (44, 'Deniz Aksoy', 50, 94.68, 172.91, 'Advanced', 31.67, 2, 2200, 'Muscle Gain', '1234')
# (45, 'Zeynep Yilmaz', 22, 67.21, 179.18, 'Advanced', 20.93, 5, 2300, 'Weight Loss', '1234')
# (46, 'Merve Dogan', 52, 96.47, 158.1, 'Beginner', 38.59, 4, 2400, 'Endurance', '1234')
# (47, 'Burak Yildirim', 56, 66.3, 179.68, 'Beginner', 20.54, 5, 2100, 'Endurance', '1234')
# (48, 'Ayse Korkmaz', 41, 69.04, 157.61, 'Intermediate', 27.79, 4, 2600, 'Muscle Gain', '1234')
# (49, 'Fatma Celik', 43, 94.06, 154.49, 'Beginner', 39.41, 1, 2800, 'Endurance', '1234')
# (50, 'Cem Koc', 29, 99.74, 159.62, 'Beginner', 39.15, 5, 2500, 'Endurance', '1234')
# (51, 'Zeynep Sahin', 39, 56.14, 152.47, 'Advanced', 24.15, 3, 2200, 'Weight Loss', '1234')
# (52, 'Deniz Dogan', 35, 74.84, 161.38, 'Beginner', 28.74, 3, 2300, 'Weight Loss', '1234')
# (53, 'Ahmet Yildirim', 25, 71.16, 156.89, 'Advanced', 28.91, 1, 2400, 'Muscle Gain', '1234')
# (54, 'Ali Aksoy', 38, 66.08, 158.06, 'Intermediate', 26.45, 5, 2100, 'Endurance', '1234')
# (55, 'Emre Korkmaz', 64, 98.7, 186.73, 'Beginner', 28.31, 2, 2600, 'Muscle Gain', '1234')
# (56, 'Zeynep Celik', 62, 56.76, 181.5, 'Beginner', 17.23, 2, 2800, 'Muscle Gain', '1234')
# (57, 'Can Kaya', 34, 65.72, 161.94, 'Beginner', '25.Haz', 2, 2450, 'Endurance', '1234')
# (58, 'Merve Guler', 65, 65.11, 176.94, 'Intermediate', '20.Aðu', 1, 2560, 'Weight Loss', '1234')
# (59, 'Ezgi Celik', 58, 83.81, 172.04, 'Beginner', 28.32, 4, 2940, 'Weight Loss', '1234')
# (60, 'Buse Guler', 34, 91.16, 156.98, 'Beginner', 36.99, 5, 3120, 'Weight Loss', '1234')
# (61, 'Merve Arslan', 45, 67.65, 184.52, 'Advanced', 19.87, 5, 3250, 'Endurance', '1234')
# (62, 'Deniz Demir', 55, 67.83, 150.0, 'Advanced', 30.15, 4, 2940, 'Weight Loss', '1234')
# (63, 'Burak Arslan', 64, 99.99, 152.08, 'Advanced', 43.23, 3, 2130, 'Endurance', '1234')
# (64, 'Mehmet Demir', 52, 71.77, 169.59, 'Advanced', 24.95, 5, 2500, 'Weight Loss', '1234')
# (65, 'Ayse Celik', 26, 90.44, 159.3, 'Beginner', 35.64, 3, 2200, 'Weight Loss', '1234')
# (66, 'Can Arslan', 48, 93.0, 165.04, 'Intermediate', 34.14, 1, 2300, 'Weight Loss', '1234')
# (67, 'Oguz Aydin', 47, 62.1, 177.2, 'Advanced', 19.78, 2, 2400, 'Weight Loss', '1234')
# (68, 'Emre Ozturk', 51, 60.22, 156.68, 'Intermediate', 24.53, 1, 2100, 'Muscle Gain', '1234')
# (69, 'Cem Polat', 44, 67.81, 188.32, 'Beginner', '19.Ara', 3, 2600, 'Weight Loss', '1234')
# (70, 'Ezgi Dogan', 64, 89.14, 164.43, 'Beginner', 32.97, 2, 2800, 'Weight Loss', '1234')
# (71, 'Ayse Demir', 44, 83.66, 161.8, 'Advanced', 31.96, 2, 2500, 'Weight Loss', '1234')
# (72, 'Ayse Arslan', 38, 69.08, 187.5, 'Advanced', 19.65, 4, 2200, 'Endurance', '1234')
# (73, 'Burak Aydin', 42, 93.91, 180.62, 'Advanced', 28.79, 5, 2300, 'Weight Loss', '1234')
# (74, 'Fatma Demir', 28, 74.48, 183.81, 'Intermediate', '22.Nis', 5, 2400, 'Weight Loss', '1234')
# (75, 'Emre Kaya', 50, 62.77, 178.49, 'Beginner', '19.Tem', 3, 2100, 'Muscle Gain', '1234')
# (76, 'Ayse Sahin', 51, 96.76, 178.92, 'Intermediate', 30.23, 3, 2600, 'Endurance', '1234')
# (77, 'Can Aydin', 53, 56.09, 169.77, 'Intermediate', 19.46, 1, 2800, 'Muscle Gain', '1234')
# (78, 'Oguz Yildirim', 29, 67.52, 152.46, 'Beginner', '29.May', 5, 2450, 'Endurance', '1234')
# (79, 'Buse Aydin', 63, 71.11, 188.36, 'Advanced', '20.Nis', 2, 2560, 'Muscle Gain', '1234')
# (80, 'Deniz Guler', 52, 72.31, 161.49, 'Intermediate', 27.73, 5, 2940, 'Weight Loss', '1234')
# (81, 'Ahmet Kaya', 49, 87.73, 157.48, 'Advanced', 35.38, 2, 3120, 'Muscle Gain', '1234')
# (82, 'Merve Sahin', 40, 68.57, 170.62, 'Beginner', 23.55, 1, 3250, 'Weight Loss', '1234')
# (83, 'Ahmet Polat', 57, 71.36, 154.15, 'Advanced', '30.Mar', 5, 2940, 'Muscle Gain', '1234')
# (84, 'Ezgi Aydin', 50, 72.97, 160.6, 'Beginner', 28.29, 2, 2130, 'Muscle Gain', '1234')
# (85, 'Zeynep Demir', 18, 79.8, 185.95, 'Intermediate', '23.Aðu', 5, 2450, 'Muscle Gain', '1234')
# (86, 'Ayse Yilmaz', 38, 94.52, 182.71, 'Advanced', 28.31, 5, 2560, 'Endurance', '1234')
# (87, 'Ezgi Yildirim', 36, 82.45, 165.36, 'Beginner', 30.15, 3, 2940, 'Weight Loss', '1234')
# (88, 'Zeynep Sahin', 39, 97.22, 183.46, 'Beginner', 28.89, 5, 3120, 'Endurance', '1234')
# (89, 'Ahmet Koc', 53, 78.48, 154.77, 'Beginner', 32.76, 3, 3250, 'Muscle Gain', '1234')
# (90, 'Burak Yilmaz', 51, 77.9, 175.61, 'Advanced', 25.26, 3, 2940, 'Endurance', '1234')
# (91, 'Merve Guler', 29, 70.46, 155.06, 'Intermediate', 29.31, 4, 2450, 'Endurance', '1234')
# (92, 'Zeynep Guler', 25, 90.77, 157.24, 'Intermediate', 36.71, 1, 2560, 'Weight Loss', '1234')
# (93, 'Emre Guler', 35, 86.89, 163.18, 'Intermediate', 32.63, 2, 2940, 'Muscle Gain', '1234')
# (94, 'Ali Arslan', 58, 59.8, 174.37, 'Advanced', 19.67, 5, 3120, 'Muscle Gain', '1234')
# (95, 'Ahmet Guler', 27, 72.0, 157.7, 'Intermediate', 28.95, 2, 3250, 'Endurance', '1234')
# (96, 'Ayse Yilmaz', 52, 61.61, 175.75, 'Advanced', 19.95, 3, 2940, 'Muscle Gain', '1234')
# (97, 'Deniz Aydin', 26, 68.36, 150.63, 'Advanced', 30.13, 2, 2450, 'Weight Loss', '1234')
# (98, 'Ahmet Aksoy', 52, 89.39, 173.97, 'Intermediate', 29.54, 1, 2560, 'Muscle Gain', '1234')
# (99, 'Deniz Ozturk', 46, 70.73, 186.03, 'Advanced', 20.44, 4, 2940, 'Weight Loss', '1234')
# (100, 'Emre Aydin', 59, 93.1, 158.18, 'Beginner', 37.21, 2, 3120, 'Muscle Gain', '1234')
#
# --- WorkoutPlans ---
# id, user_id, workout_data
#
# --- UserFitnessData ---
# id, user_id, date, exercise_name, weight, sets, reps
#
# --- Exercises ---
# id, exercise_name, body_part, sets, reps, equipment
# (1, 'Bench Press', 'Gogus', 3, 8, 'Barbell')
# (2, 'Incline Bench Press', 'Gogus', 3, 8, 'Barbell')
# (3, 'Chest Fly', 'Gogus', 4, 10, 'Dumbbell')
# (4, 'Push-Up', 'Gogus', 3, 10, 'Bodyweight')
# (5, 'Cable Crossover', 'Gogus', 4, 8, 'Cable')
# (6, 'Dumbbell Bench Press', 'Gogus', 3, 10, 'Dumbbell')
# (7, 'Pec Deck Machine', 'Gogus', 3, 12, 'Machine')
# (8, 'Decline Bench Press', 'Gogus', 3, 14, 'Barbell')
# (9, 'Dips', 'Gogus', 3, 10, 'Bodyweight')
# (10, 'Landmine Press', 'Gogus', 4, 8, 'Barbell')
# (11, 'Overhead Press', 'Omuz', 3, 12, 'Barbell')
# (12, 'Lateral Raise', 'Omuz', 4, 10, 'Dumbbell')
# (13, 'Front Raise', 'Omuz', 4, 8, 'Dumbbell')
# (14, 'Arnold Press', 'Omuz', 3, 12, 'Dumbbell')
# (15, 'Machine Shoulder Press', 'Omuz', 3, 14, 'Machine')
# (16, 'Cable Face Pull', 'Omuz', 4, 10, 'Cable')
# (17, 'Reverse Fly', 'Omuz', 3, 15, 'Dumbbell')
# (18, 'Seated Dumbbell Press', 'Omuz', 4, 12, 'Dumbbell')
# (19, 'Upright Row', 'Omuz', 3, 15, 'Barbell')
# (20, 'Dumbbell Shrug', 'Omuz', 4, 10, 'Dumbbell')
# (21, 'Barbell Curl', 'Biceps', 4, 8, 'Barbell')
# (22, 'Dumbbell Curl', 'Biceps', 3, 10, 'Dumbbell')
# (23, 'Concentration Curl', 'Biceps', 3, 8, 'Dumbbell')
# (24, 'Hammer Curl', 'Biceps', 3, 8, 'Dumbbell')
# (25, 'Preacher Curl', 'Biceps', 3, 12, 'Barbell or Dumbbell')
# (26, 'Cable Curl', 'Biceps', 4, 10, 'Cable')
# (27, 'Incline Dumbbell Curl', 'Biceps', 3, 14, 'Dumbbell')
# (28, 'Zottman Curl', 'Biceps', 3, 16, 'Dumbbell')
# (29, 'Reverse Curl', 'Biceps', 3, 8, 'Barbell')
# (30, 'Spider Curl', 'Biceps', 4, 8, 'Barbell or Dumbbell')
# (31, 'Wrist Curl', 'On Kol', 3, 10, 'Dumbbell')
# (32, 'Reverse Wrist Curl', 'On Kol', 3, 10, 'Dumbbell')
# (33, "Farmer's Walk", 'On Kol', 3, 8, 'Dumbbell')
# (34, 'Reverse Curl', 'On Kol', 3, 10, 'Barbell')
# (35, 'Zottman Curl', 'On Kol', 3, 12, 'Dumbbell')
# (36, 'Hammer Curl', 'On Kol', 4, 14, 'Dumbbell')
# (37, 'Preacher Curl', 'On Kol', 3, 10, 'Dumbbell')
# (38, 'Plate Pinch', 'On Kol', 3, 8, 'Plate')
# (39, 'Cable Curl', 'On Kol', 4, 12, 'Cable')
# (40, 'Reverse Barbell Curl', 'On Kol', 4, 10, 'Barbell')
# (41, 'Tricep Pushdown', 'Arka Kol', 3, 8, 'Cable')
# (42, 'Skull Crushers', 'Arka Kol', 4, 12, 'Barbell')
# (43, 'Dips', 'Arka Kol', 3, 14, 'Bodyweight')
# (44, 'Close Grip Bench Press', 'Arka Kol', 3, 10, 'Barbell')
# (45, 'Overhead Tricep Extension', 'Arka Kol', 4, 15, 'Dumbbell')
# (46, 'Tricep Kickback', 'Arka Kol', 3, 12, 'Dumbbell')
# (47, 'Rope Tricep Extension', 'Arka Kol', 4, 15, 'Cable')
# (48, 'Tricep Dips (Bench)', 'Arka Kol', 3, 10, 'Bodyweight')
# (49, 'One-Arm Overhead Extension', 'Arka Kol', 3, 8, 'Dumbbell')
# (50, 'Cable Overhead Tricep Extension', 'Arka Kol', 4, 10, 'Cable')
# (51, 'Pull-Up', 'Sirt', 3, 8, 'Bodyweight')
# (52, 'Lat Pulldown', 'Sirt', 4, 8, 'Cable')
# (53, 'Barbell Row', 'Sirt', 3, 12, 'Barbell')
# (54, 'Deadlift', 'Sirt', 4, 10, 'Barbell')
# (55, 'T-Bar Row', 'Sirt', 4, 14, 'Barbell')
# (56, 'Seated Row', 'Sirt', 3, 16, 'Cable')
# (57, 'Dumbbell Row', 'Sirt', 3, 8, 'Dumbbell')
# (58, 'Face Pull', 'Sirt', 3, 10, 'Cable')
# (59, 'Hyperextension', 'Sirt', 4, 8, 'Bodyweight')
# (60, 'Chin-Up', 'Sirt', 3, 8, 'Bodyweight')
# (61, 'Squat', 'Bacak', 4, 12, 'Barbell')
# (62, 'Leg Press', 'Bacak', 4, 10, 'Machine')
# (63, 'Lunges', 'Bacak', 3, 14, 'Bodyweight or Dumbbell')
# (64, 'Romanian Deadlift', 'Bacak', 3, 16, 'Barbell')
# (65, 'Leg Curl', 'Bacak', 4, 8, 'Machine')
# (66, 'Leg Extension', 'Bacak', 3, 10, 'Machine')
# (67, 'Bulgarian Split Squat', 'Bacak', 3, 8, 'Dumbbell')
# (68, 'Calf Raise', 'Bacak', 4, 8, 'Machine or Dumbbell')
# (69, 'Hack Squat', 'Bacak', 4, 12, 'Machine')
# (70, 'Step-Up', 'Bacak', 3, 10, 'Dumbbell')
